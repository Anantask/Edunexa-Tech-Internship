# %% [markdown]
# #TASK 3-EXPLANATORY DATA ANALYSIS

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random as rd

# %%
df=pd.read_csv(r"C:\Users\Ananta\Downloads\healthcare.csv")
df
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318453             19                  a                   7
# 1        318452             28                  b                  11
# 2        318451             16                  c                   3
# 3        318450              4                  a                   4
# 4        318449             10                  e                   1
# ...         ...            ...                ...                 ...
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                         Y                                  1    gynecology
# 1                         X                                  3    gynecology
# 2                         Z                                  4    gynecology
# 3                         X                                  3    gynecology
# 4                         X                                  4    gynecology
# ...                     ...                                ...           ...
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0              S                  C        2.0      40728                8.0
# 1              R                  F        4.0      95946                NaN
# 2              R                  A        3.0      95946                NaN
# 3              R                  F        3.0      95946                NaN
# 4              Q                  E        2.0      95946                NaN
# ...          ...                ...        ...        ...                ...
# 137052         Q                  D        3.0      41160                3.0
# 137053         R                  E        4.0      30985                7.0
# 137054         R                  A        4.0      81811               12.0
# 137055         R                  E        4.0      57021               10.0
# 137056         Q                  F        4.0     126729                3.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0              Emergency            Moderate                      4  51-60
# 1                 Urgent            Moderate                      2  31-40
# 2                 Trauma            Moderate                      3  31-40
# 3              Emergency            Moderate                      6  31-40
# 4                 Trauma            Moderate                      2  31-40
# ...                  ...                 ...                    ...    ...
# 137052         Emergency               Minor                      4  41-50
# 137053         Emergency            Moderate                      2   0-10
# 137054            Urgent               Minor                      2   0-10
# 137055            Trauma               Minor                      2  41-50
# 137056            Trauma             Extreme                      5  51-60
#
#         Admission_Deposit
# 0                    3288
# 1                    4315
# 2                    4322
# 3                    3468
# 4                    4241
# ...                   ...
# 137052               6313
# 137053               3510
# 137054               7190
# 137055               5435
# 137056               4702
#
# [137057 rows x 17 columns]

# %%
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318453             19                  a                   7
# 1   318452             28                  b                  11
# 2   318451             16                  c                   3
# 3   318450              4                  a                   4
# 4   318449             10                  e                   1
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Y                                  1  gynecology
# 1                    X                                  3  gynecology
# 2                    Z                                  4  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  4  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  C        2.0      40728                8.0
# 1         R                  F        4.0      95946                NaN
# 2         R                  A        3.0      95946                NaN
# 3         R                  F        3.0      95946                NaN
# 4         Q                  E        2.0      95946                NaN
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                      4  51-60
# 1            Urgent            Moderate                      2  31-40
# 2            Trauma            Moderate                      3  31-40
# 3         Emergency            Moderate                      6  31-40
# 4            Trauma            Moderate                      2  31-40
#
#    Admission_Deposit
# 0               3288
# 1               4315
# 2               4322
# 3               3468
# 4               4241

# %%
df.tail()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 137052         Q                  D        3.0      41160                3.0
# 137053         R                  E        4.0      30985                7.0
# 137054         R                  A        4.0      81811               12.0
# 137055         R                  E        4.0      57021               10.0
# 137056         Q                  F        4.0     126729                3.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 137052         Emergency               Minor                      4  41-50
# 137053         Emergency            Moderate                      2   0-10
# 137054            Urgent               Minor                      2   0-10
# 137055            Trauma               Minor                      2  41-50
# 137056            Trauma             Extreme                      5  51-60
#
#         Admission_Deposit
# 137052               6313
# 137053               3510
# 137054               7190
# 137055               5435
# 137056               4702

# %%
df.shape
# Out:
# (137057, 17)

# %%
df.head().describe
# Out:
# <bound method NDFrame.describe of    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318453             19                  a                   7
# 1   318452             28                  b                  11
# 2   318451             16                  c                   3
# 3   318450              4                  a                   4
# 4   318449             10                  e                   1
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Y                                  1  gynecology
# 1                    X                                  3  gynecology
# 2                    Z                                  4  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  4  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  C        2.0      40728                8.0
# 1         R                  F        4.0      95946                NaN
# 2         R                  A        3.0      95946                NaN
# 3         R                  F        3.0      95946                NaN
# 4         Q                  E        2.0      95946                NaN
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                      4  51-60
# 1            Urgent            Moderate                      2  31-40
# 2            Trauma            Moderate                      3  31-40
# 3         Emergency            Moderate                      6  31-40
# 4            Trauma            Moderate                      2  31-40
#
#    Admission_Deposit
# 0               3288
# 1               4315
# 2               4322
# 3               3468
# 4               4241  >

# %%
df.isnull()
# Out:
#         case_id  Hospital_code  Hospital_type_code  City_Code_Hospital  \
# 0         False          False               False               False
# 1         False          False               False               False
# 2         False          False               False               False
# 3         False          False               False               False
# 4         False          False               False               False
# ...         ...            ...                 ...                 ...
# 137052    False          False               False               False
# 137053    False          False               False               False
# 137054    False          False               False               False
# 137055    False          False               False               False
# 137056    False          False               False               False
#
#         Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                      False                              False       False
# 1                      False                              False       False
# 2                      False                              False       False
# 3                      False                              False       False
# 4                      False                              False       False
# ...                      ...                                ...         ...
# 137052                 False                              False       False
# 137053                 False                              False       False
# 137054                 False                              False       False
# 137055                 False                              False       False
# 137056                 False                              False       False
#
#         Ward_Type  Ward_Facility_Code  Bed Grade  patientid  \
# 0           False               False      False      False
# 1           False               False      False      False
# 2           False               False      False      False
# 3           False               False      False      False
# 4           False               False      False      False
# ...           ...                 ...        ...        ...
# 137052      False               False      False      False
# 137053      False               False      False      False
# 137054      False               False      False      False
# 137055      False               False      False      False
# 137056      False               False      False      False
#
#         City_Code_Patient  Type of Admission  Severity of Illness  \
# 0                   False              False                False
# 1                    True              False                False
# 2                    True              False                False
# 3                    True              False                False
# 4                    True              False                False
# ...                   ...                ...                  ...
# 137052              False              False                False
# 137053              False              False                False
# 137054              False              False                False
# 137055              False              False                False
# 137056              False              False                False
#
#         Visitors with Patient    Age  Admission_Deposit
# 0                       False  False              False
# 1                       False  False              False
# 2                       False  False              False
# 3                       False  False              False
# 4                       False  False              False
# ...                       ...    ...                ...
# 137052                  False  False              False
# 137053                  False  False              False
# 137054                  False  False              False
# 137055                  False  False              False
# 137056                  False  False              False
#
# [137057 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# case_id                                 0
# Hospital_code                           0
# Hospital_type_code                      0
# City_Code_Hospital                      0
# Hospital_region_code                    0
# Available Extra Rooms in Hospital       0
# Department                              0
# Ward_Type                               0
# Ward_Facility_Code                      0
# Bed Grade                              35
# patientid                               0
# City_Code_Patient                    2157
# Type of Admission                       0
# Severity of Illness                     0
# Visitors with Patient                   0
# Age                                     0
# Admission_Deposit                       0
# dtype: int64

# %%
df.isnull().any()
# Out:
# case_id                              False
# Hospital_code                        False
# Hospital_type_code                   False
# City_Code_Hospital                   False
# Hospital_region_code                 False
# Available Extra Rooms in Hospital    False
# Department                           False
# Ward_Type                            False
# Ward_Facility_Code                   False
# Bed Grade                             True
# patientid                            False
# City_Code_Patient                     True
# Type of Admission                    False
# Severity of Illness                  False
# Visitors with Patient                False
# Age                                  False
# Admission_Deposit                    False
# dtype: bool

# %%
df.columns
# Out:
# Index(['case_id', 'Hospital_code', 'Hospital_type_code', 'City_Code_Hospital',
#        'Hospital_region_code', 'Available Extra Rooms in Hospital',
#        'Department', 'Ward_Type', 'Ward_Facility_Code', 'Bed Grade',
#        'patientid', 'City_Code_Patient', 'Type of Admission',
#        'Severity of Illness', 'Visitors with Patient', 'Age',
#        'Admission_Deposit'],
#       dtype='object')

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318453             19                  a                   7
# 1        318452             28                  b                  11
# 2        318451             16                  c                   3
# 3        318450              4                  a                   4
# 4        318449             10                  e                   1
# ...         ...            ...                ...                 ...
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                         Y                                  1    gynecology
# 1                         X                                  3    gynecology
# 2                         Z                                  4    gynecology
# 3                         X                                  3    gynecology
# 4                         X                                  4    gynecology
# ...                     ...                                ...           ...
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0              S                  C        2.0      40728                8.0
# 1              R                  F        4.0      95946                NaN
# 2              R                  A        3.0      95946                NaN
# 3              R                  F        3.0      95946                NaN
# 4              Q                  E        2.0      95946                NaN
# ...          ...                ...        ...        ...                ...
# 137052         Q                  D        3.0      41160                3.0
# 137053         R                  E        4.0      30985                7.0
# 137054         R                  A        4.0      81811               12.0
# 137055         R                  E        4.0      57021               10.0
# 137056         Q                  F        4.0     126729                3.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0              Emergency            Moderate                      4  51-60
# 1                 Urgent            Moderate                      2  31-40
# 2                 Trauma            Moderate                      3  31-40
# 3              Emergency            Moderate                      6  31-40
# 4                 Trauma            Moderate                      2  31-40
# ...                  ...                 ...                    ...    ...
# 137052         Emergency               Minor                      4  41-50
# 137053         Emergency            Moderate                      2   0-10
# 137054            Urgent               Minor                      2   0-10
# 137055            Trauma               Minor                      2  41-50
# 137056            Trauma             Extreme                      5  51-60
#
#         Admission_Deposit
# 0                    3288
# 1                    4315
# 2                    4322
# 3                    3468
# 4                    4241
# ...                   ...
# 137052               6313
# 137053               3510
# 137054               7190
# 137055               5435
# 137056               4702
#
# [137057 rows x 17 columns]>

# %%
df.dropna()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318453             19                  a                   7
# 8        318445             26                  b                   2
# 9        318444             23                  a                   6
# 10       318443             28                  b                  11
# 11       318442              6                  a                   6
# ...         ...            ...                ...                 ...
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                         Y                                  1    gynecology
# 8                         Y                                  2    gynecology
# 9                         X                                  3    gynecology
# 10                        X                                  2    gynecology
# 11                        X                                  3    gynecology
# ...                     ...                                ...           ...
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0              S                  C        2.0      40728                8.0
# 8              Q                  D        2.0      17006                2.0
# 9              Q                  F        2.0      17006                2.0
# 10             R                  F        2.0      17006                2.0
# 11             Q                  F        2.0      17006                2.0
# ...          ...                ...        ...        ...                ...
# 137052         Q                  D        3.0      41160                3.0
# 137053         R                  E        4.0      30985                7.0
# 137054         R                  A        4.0      81811               12.0
# 137055         R                  E        4.0      57021               10.0
# 137056         Q                  F        4.0     126729                3.0
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0              Emergency            Moderate                      4  51-60
# 8                 Trauma            Moderate                      2  71-80
# 9                 Trauma            Moderate                      2  71-80
# 10                Trauma            Moderate                      4  71-80
# 11                Trauma            Moderate                      3  71-80
# ...                  ...                 ...                    ...    ...
# 137052         Emergency               Minor                      4  41-50
# 137053         Emergency            Moderate                      2   0-10
# 137054            Urgent               Minor                      2   0-10
# 137055            Trauma               Minor                      2  41-50
# 137056            Trauma             Extreme                      5  51-60
#
#         Admission_Deposit
# 0                    3288
# 8                    4167
# 9                    4659
# 10                   4161
# 11                   4173
# ...                   ...
# 137052               6313
# 137053               3510
# 137054               7190
# 137055               5435
# 137056               4702
#
# [134865 rows x 17 columns]

# %%
df.interpolate()
# Out:
#         case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0        318453             19                  a                   7
# 1        318452             28                  b                  11
# 2        318451             16                  c                   3
# 3        318450              4                  a                   4
# 4        318449             10                  e                   1
# ...         ...            ...                ...                 ...
# 137052   455491             11                  b                   2
# 137053   455492             25                  e                   1
# 137054   455493             30                  c                   3
# 137055   455494              5                  a                   1
# 137056   455495              6                  a                   6
#
#        Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# 0                         Y                                  1    gynecology
# 1                         X                                  3    gynecology
# 2                         Z                                  4    gynecology
# 3                         X                                  3    gynecology
# 4                         X                                  4    gynecology
# ...                     ...                                ...           ...
# 137052                    Y                                  4    anesthesia
# 137053                    X                                  2  radiotherapy
# 137054                    Z                                  2    anesthesia
# 137055                    X                                  2    anesthesia
# 137056                    X                                  3    gynecology
#
#        Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0              S                  C        2.0      40728               8.00
# 1              R                  F        4.0      95946               7.25
# 2              R                  A        3.0      95946               6.50
# 3              R                  F        3.0      95946               5.75
# 4              Q                  E        2.0      95946               5.00
# ...          ...                ...        ...        ...                ...
# 137052         Q                  D        3.0      41160               3.00
# 137053         R                  E        4.0      30985               7.00
# 137054         R                  A        4.0      81811              12.00
# 137055         R                  E        4.0      57021              10.00
# 137056         Q                  F        4.0     126729               3.00
#
#        Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0              Emergency            Moderate                      4  51-60
# 1                 Urgent            Moderate                      2  31-40
# 2                 Trauma            Moderate                      3  31-40
# 3              Emergency            Moderate                      6  31-40
# 4                 Trauma            Moderate                      2  31-40
# ...                  ...                 ...                    ...    ...
# 137052         Emergency               Minor                      4  41-50
# 137053         Emergency            Moderate                      2   0-10
# 137054            Urgent               Minor                      2   0-10
# 137055            Trauma               Minor                      2  41-50
# 137056            Trauma             Extreme                      5  51-60
#
#         Admission_Deposit
# 0                    3288
# 1                    4315
# 2                    4322
# 3                    3468
# 4                    4241
# ...                   ...
# 137052               6313
# 137053               3510
# 137054               7190
# 137055               5435
# 137056               4702
#
# [137057 rows x 17 columns]

# %%
healthcare=df.drop(['Bed Grade'], axis=1)
df.head()
# Out:
#    case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0   318453             19                  a                   7
# 1   318452             28                  b                  11
# 2   318451             16                  c                   3
# 3   318450              4                  a                   4
# 4   318449             10                  e                   1
#
#   Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                    Y                                  1  gynecology
# 1                    X                                  3  gynecology
# 2                    Z                                  4  gynecology
# 3                    X                                  3  gynecology
# 4                    X                                  4  gynecology
#
#   Ward_Type Ward_Facility_Code  Bed Grade  patientid  City_Code_Patient  \
# 0         S                  C        2.0      40728                8.0
# 1         R                  F        4.0      95946                NaN
# 2         R                  A        3.0      95946                NaN
# 3         R                  F        3.0      95946                NaN
# 4         Q                  E        2.0      95946                NaN
#
#   Type of Admission Severity of Illness  Visitors with Patient    Age  \
# 0         Emergency            Moderate                      4  51-60
# 1            Urgent            Moderate                      2  31-40
# 2            Trauma            Moderate                      3  31-40
# 3         Emergency            Moderate                      6  31-40
# 4            Trauma            Moderate                      2  31-40
#
#    Admission_Deposit
# 0               3288
# 1               4315
# 2               4322
# 3               3468
# 4               4241

# %%
correlation=healthcare.corr()
# Out:
# C:\Users\Ananta\AppData\Local\Temp\ipykernel_13160\68592649.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation=healthcare.corr()

# %%
sns.heatmap(correlation,xticklabels=correlation.columns ,yticklabels=correlation.columns ,annot=True)
# Out:
# <Axes: >
