# %% [markdown]
# TASK1-EXPLORING DATASET

# %%
import numpy as numpy
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Ananta\Downloads\News.csv")
df
# Out:
#        Title     PATIENT NAME                  Date             MEDICINES  \
# 0  PATIENT 3    Sean Michaels  2023-03-22T22:00:00Z  PANTAPRAZOLE-D 500MG
# 1  PATIENT 2  Daniel Williams  2023-03-21T22:00:00Z           SINAREST LP
# 2  PATIENT 6     Kim Jennings  2023-03-20T22:00:00Z              BANOCIDE
# 3  PATIENT 4     Sarah Jones   2023-03-19T22:00:00Z     PAN-D,SINAREST LP
# 4  PATIENT 5     Derek Wells   2023-03-18T22:00:00Z         EVION TABLETS
# 5  PATIENT 1     Jess Wilder   2023-03-17T22:00:00Z           PARACETAMOL
#
#                                              DISEASE  \
# 0  {"nodes":[{"type":"PARAGRAPH","id":"8ujtn","no...
# 1  {"nodes":[{"type":"PARAGRAPH","id":"4p226","no...
# 2  {"nodes":[{"type":"PARAGRAPH","id":"eci8i","no...
# 3  {"nodes":[{"type":"PARAGRAPH","id":"feit4","no...
# 4  {"nodes":[{"type":"PARAGRAPH","id":"3u4ue","no...
# 5  {"nodes":[{"type":"PARAGRAPH","id":"ahict","no...
#
#                                      ID          Updated Date  \
# ...

# %%
df.head()
# Out:
#        Title     PATIENT NAME                  Date             MEDICINES  \
# 0  PATIENT 3    Sean Michaels  2023-03-22T22:00:00Z  PANTAPRAZOLE-D 500MG
# 1  PATIENT 2  Daniel Williams  2023-03-21T22:00:00Z           SINAREST LP
# 2  PATIENT 6     Kim Jennings  2023-03-20T22:00:00Z              BANOCIDE
# 3  PATIENT 4     Sarah Jones   2023-03-19T22:00:00Z     PAN-D,SINAREST LP
# 4  PATIENT 5     Derek Wells   2023-03-18T22:00:00Z         EVION TABLETS
#
#                                              DISEASE  \
# 0  {"nodes":[{"type":"PARAGRAPH","id":"8ujtn","no...
# 1  {"nodes":[{"type":"PARAGRAPH","id":"4p226","no...
# 2  {"nodes":[{"type":"PARAGRAPH","id":"eci8i","no...
# 3  {"nodes":[{"type":"PARAGRAPH","id":"feit4","no...
# 4  {"nodes":[{"type":"PARAGRAPH","id":"3u4ue","no...
#
#                                      ID          Updated Date  \
# 0  00000000-0000-0000-0000-000000000001  2023-10-15T13:22:54Z
# 1  00000000-0000-0000-0000-000000000002  2023-10-15T13:22:50Z
# ...

# %%
df.tail()
# Out:
#        Title     PATIENT NAME                  Date          MEDICINES  \
# 1  PATIENT 2  Daniel Williams  2023-03-21T22:00:00Z        SINAREST LP
# 2  PATIENT 6     Kim Jennings  2023-03-20T22:00:00Z           BANOCIDE
# 3  PATIENT 4     Sarah Jones   2023-03-19T22:00:00Z  PAN-D,SINAREST LP
# 4  PATIENT 5     Derek Wells   2023-03-18T22:00:00Z      EVION TABLETS
# 5  PATIENT 1     Jess Wilder   2023-03-17T22:00:00Z        PARACETAMOL
#
#                                              DISEASE  \
# 1  {"nodes":[{"type":"PARAGRAPH","id":"4p226","no...
# 2  {"nodes":[{"type":"PARAGRAPH","id":"eci8i","no...
# 3  {"nodes":[{"type":"PARAGRAPH","id":"feit4","no...
# 4  {"nodes":[{"type":"PARAGRAPH","id":"3u4ue","no...
# 5  {"nodes":[{"type":"PARAGRAPH","id":"ahict","no...
#
#                                      ID          Updated Date  \
# 1  00000000-0000-0000-0000-000000000002  2023-10-15T13:22:50Z
# 2  00000000-0000-0000-0000-000000000003  2023-10-15T13:23:08Z
# ...

# %%
df.describe()
# Out:
#             Title   PATIENT NAME                  Date             MEDICINES  \
# count           6              6                     6                     6
# unique          6              6                     6                     6
# top     PATIENT 3  Sean Michaels  2023-03-22T22:00:00Z  PANTAPRAZOLE-D 500MG
# freq            1              1                     1                     1
#
#                                                   DISEASE  \
# count                                                   6
# unique                                                  6
# top     {"nodes":[{"type":"PARAGRAPH","id":"8ujtn","no...
# freq                                                    1
#
#                                           ID          Updated Date  \
# count                                      6                     6
# unique                                     6                     6
# top     00000000-0000-0000-0000-000000000001  2023-10-15T13:22:54Z
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Title     PATIENT NAME                  Date             MEDICINES  \
# 0  PATIENT 3    Sean Michaels  2023-03-22T22:00:00Z  PANTAPRAZOLE-D 500MG
# 1  PATIENT 2  Daniel Williams  2023-03-21T22:00:00Z           SINAREST LP
# 2  PATIENT 6     Kim Jennings  2023-03-20T22:00:00Z              BANOCIDE
# 3  PATIENT 4     Sarah Jones   2023-03-19T22:00:00Z     PAN-D,SINAREST LP
# 4  PATIENT 5     Derek Wells   2023-03-18T22:00:00Z         EVION TABLETS
# 5  PATIENT 1     Jess Wilder   2023-03-17T22:00:00Z           PARACETAMOL
#
#                                              DISEASE  \
# 0  {"nodes":[{"type":"PARAGRAPH","id":"8ujtn","no...
# 1  {"nodes":[{"type":"PARAGRAPH","id":"4p226","no...
# 2  {"nodes":[{"type":"PARAGRAPH","id":"eci8i","no...
# 3  {"nodes":[{"type":"PARAGRAPH","id":"feit4","no...
# 4  {"nodes":[{"type":"PARAGRAPH","id":"3u4ue","no...
# 5  {"nodes":[{"type":"PARAGRAPH","id":"ahict","no...
#
# ...

# %%
df.shape
# Out:
# (6, 11)

# %%
df.isnull()
# Out:
#    Title  PATIENT NAME   Date  MEDICINES  DISEASE     ID  Updated Date  \
# 0  False         False  False      False    False  False         False
# 1  False         False  False      False    False  False         False
# 2  False         False  False      False    False  False         False
# 3  False         False  False      False    False  False         False
# 4  False         False  False      False    False  False         False
# 5  False         False  False      False    False  False         False
#
#    Created Date  Owner  News (Title)  PHARMACY DATA
# 0         False  False         False          False
# 1         False  False         False          False
# 2         False  False         False          False
# 3         False  False         False          False
# 4         False  False         False          False
# 5         False  False         False          False

# %%
df.isnull().sum()
# Out:
# Title            0
# PATIENT NAME     0
# Date             0
# MEDICINES        0
# DISEASE          0
# ID               0
# Updated Date     0
# Created Date     0
# Owner            0
# News (Title)     0
# PHARMACY DATA    0
# dtype: int64

# %%
df.dropna()
# Out:
#        Title     PATIENT NAME                  Date             MEDICINES  \
# 0  PATIENT 3    Sean Michaels  2023-03-22T22:00:00Z  PANTAPRAZOLE-D 500MG
# 1  PATIENT 2  Daniel Williams  2023-03-21T22:00:00Z           SINAREST LP
# 2  PATIENT 6     Kim Jennings  2023-03-20T22:00:00Z              BANOCIDE
# 3  PATIENT 4     Sarah Jones   2023-03-19T22:00:00Z     PAN-D,SINAREST LP
# 4  PATIENT 5     Derek Wells   2023-03-18T22:00:00Z         EVION TABLETS
# 5  PATIENT 1     Jess Wilder   2023-03-17T22:00:00Z           PARACETAMOL
#
#                                              DISEASE  \
# 0  {"nodes":[{"type":"PARAGRAPH","id":"8ujtn","no...
# 1  {"nodes":[{"type":"PARAGRAPH","id":"4p226","no...
# 2  {"nodes":[{"type":"PARAGRAPH","id":"eci8i","no...
# 3  {"nodes":[{"type":"PARAGRAPH","id":"feit4","no...
# 4  {"nodes":[{"type":"PARAGRAPH","id":"3u4ue","no...
# 5  {"nodes":[{"type":"PARAGRAPH","id":"ahict","no...
#
#                                      ID          Updated Date  \
# ...
